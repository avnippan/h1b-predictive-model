# %% [markdown]
# # Data Cleaning and Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the correct dataset, handling potential quoting and multiline issues
h1b = pd.read_csv("data/h1b_disclosure_data_2015_2019.csv", encoding='latin-1',
                  on_bad_lines='skip',  # Skip bad lines that cause errors
                  quotechar='"',          # Explicitly define the quote character
                  escapechar='\\')        # Specify escape character for special characters within strings
# Out:
# <ipython-input-4-6eb559a0d88d>:6: DtypeWarning: Columns (7,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   h1b = pd.read_csv("h1b_disclosure_data_2015_2019.csv", encoding='latin-1',

# %%
h1b.head()      # First 5 rows
# Out:
#           CASE_NUMBER          CASE_STATUS  \
# 0  I-200-09285-514415            CERTIFIED
# 1  I-200-09341-564186  CERTIFIED-WITHDRAWN
# 2  I-200-09342-274341            CERTIFIED
# 3  I-200-09364-425868            CERTIFIED
# 4  I-200-10006-413683            WITHDRAWN
#
#                           EMPLOYER_NAME  \
# 0                           IT CATS LLC
# 1              XPERT TECHNOLOGIES, INC.
# 2                    ISR INFO WAY, INC.
# 3  MAGIC CIRCLE FILMS INTERNATIONAL LLC
# 4                 SAPHIRE SOLUTIONS INC
#
#                                       SOC_NAME SOC_CODE  \
# 0                    COMPUTER SYSTEMS ANALYSTS  15-1121
# 1             COMPUTER OCCUPATIONS, ALL OTHER*  15-1799
# 2            SOFTWARE DEVELOPERS, APPLICATIONS  15-1132
# 3                       FILM AND VIDEO EDITORS  27-4032
# 4  NETWORK AND COMPUTER SYSTEMS ADMINISTRATORS  15-1142
#
#                    JOB_TITLE FULL_TIME_POSITION PREVAILING_WAGE WORKSITE_CITY  \
# 0    SENIOR BUSINESS ANALYST                  Y        109116.8  NORTH WALES,
# 1  QUALITY ASSURANCE ANALYST                  Y         58282.0     CAMP HILL
# 2     SR. SOFTWARE DEVELOPER                  Y         84906.0       CHICAGO
# 3               VIDEO EDITOR                  Y         39333.0        AUBURN
# 4      SYSTEMS ADMINISTRATOR                  Y         68638.0      BETHPAGE
#
#   WORKSITE_STATE_ABB  YEAR WORKSITE_STATE_FULL                   WORKSITE
# 0                 PA  2015        PENNSYLVANIA  NORTH WALES, PENNSYLVANIA
# 1                 PA  2015        PENNSYLVANIA    CAMP HILL, PENNSYLVANIA
# 2                 IL  2015            ILLINOIS          CHICAGO, ILLINOIS
# 3                 NY  2015            NEW YORK           AUBURN, NEW YORK
# 4                 NY  2015            NEW YORK         BETHPAGE, NEW YORK

# %%
h1b.describe()  # Statistical summary
# Out:
#                CASE_NUMBER CASE_STATUS    EMPLOYER_NAME  \
# count               857216      857216           857195
# unique              839446           4            70043
# top     I-200-15054-406343   CERTIFIED  INFOSYS LIMITED
# freq                     4      765099            23802
#
#                                  SOC_NAME SOC_CODE           JOB_TITLE  \
# count                              857210   857212              857211
# unique                               1106      867              111352
# top     SOFTWARE DEVELOPERS, APPLICATIONS  15-1132  PROGRAMMER ANALYST
# freq                               172819   173017               41003
#
#        FULL_TIME_POSITION  PREVAILING_WAGE WORKSITE_CITY WORKSITE_STATE_ABB  \
# count              857215         857212.0        857188             857216
# unique                  5          33985.0          7999                 20
# top                     Y          80912.0      NEW YORK                 NY
# freq               704915           4091.0        171385             230915
#
#           YEAR WORKSITE_STATE_FULL            WORKSITE
# count   857216              857216              857212
# unique      11                  12                7413
# top       2015            NEW YORK  NEW YORK, NEW YORK
# freq    167394              281110              171448

# %%
h1b.info()      # Data types & null counts
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857216 entries, 0 to 857215
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   CASE_NUMBER          857216 non-null  object
#  1   CASE_STATUS          857216 non-null  object
#  2   EMPLOYER_NAME        857195 non-null  object
#  3   SOC_NAME             857210 non-null  object
#  4   SOC_CODE             857212 non-null  object
#  5   JOB_TITLE            857211 non-null  object
#  6   FULL_TIME_POSITION   857215 non-null  object
#  7   PREVAILING_WAGE      857212 non-null  object
#  8   WORKSITE_CITY        857188 non-null  object
#  9   WORKSITE_STATE_ABB   857216 non-null  object
#  10  YEAR                 857216 non-null  object
#  11  WORKSITE_STATE_FULL  857216 non-null  object
#  12  WORKSITE             857212 non-null  object
# dtypes: object(13)
# memory usage: 85.0+ MB

# %%
# Visualizations

approval_rates = h1b.groupby('YEAR')['CASE_STATUS'].value_counts(normalize=True).unstack()
approval_rates.plot(kind='bar', stacked=True)
plt.title('H1B Approval Rates by Year')
plt.xlabel('Year')
plt.ylabel('Proportion')
plt.show()

# %%
plt.hist(h1b['PREVAILING_WAGE'], bins=50, range=(0, 200000))
plt.title('Distribution of Prevailing Wages')
plt.xlabel('Prevailing Wage')
plt.ylabel('Frequency')
plt.show()

# %%
state_case_status = h1b.groupby('WORKSITE_STATE_FULL')['CASE_STATUS'].value_counts().unstack()
state_case_status.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('H1B Case Status by State')
plt.xlabel('Worksite State')
plt.ylabel('Number of Cases')
plt.show()

# %%
# Handling missing values
print(h1b.isnull().sum()) #Check nulls per column
h1b_clean = h1b.dropna(subset=['PREVAILING_WAGE', 'EMPLOYER_NAME', 'FULL_TIME_POSITION', 'WORKSITE_CITY', 'JOB_TITLE', 'WORKSITE_STATE_FULL', 'YEAR'])
h1b_clean
# Out:
# CASE_NUMBER             0
# CASE_STATUS             0
# EMPLOYER_NAME          21
# SOC_NAME                6
# SOC_CODE                4
# JOB_TITLE               5
# FULL_TIME_POSITION      1
# PREVAILING_WAGE         4
# WORKSITE_CITY          28
# WORKSITE_STATE_ABB      0
# YEAR                    0
# WORKSITE_STATE_FULL     0
# WORKSITE                4
# dtype: int64
#                CASE_NUMBER          CASE_STATUS  \
# 0       I-200-09285-514415            CERTIFIED
# 1       I-200-09341-564186  CERTIFIED-WITHDRAWN
# 2       I-200-09342-274341            CERTIFIED
# 3       I-200-09364-425868            CERTIFIED
# 4       I-200-10006-413683            WITHDRAWN
# ...                    ...                  ...
# 857211  I-200-19053-522403            CERTIFIED
# 857212  I-200-18282-647333            CERTIFIED
# 857213  I-200-19046-203745               DENIED
# 857214  I-200-19059-900658               DENIED
# 857215  I-200-19073-908844               DENIED
#
#                                    EMPLOYER_NAME  \
# 0                                    IT CATS LLC
# 1                       XPERT TECHNOLOGIES, INC.
# 2                             ISR INFO WAY, INC.
# 3           MAGIC CIRCLE FILMS INTERNATIONAL LLC
# 4                          SAPHIRE SOLUTIONS INC
# ...                                          ...
# 857211                           JETBLUE AIRWAYS
# 857212  AMERICAN FAMILY MUTUAL INSURANCE COMPANY
# 857213                     CAPGEMINI AMERICA INC
# 857214                     CAPGEMINI AMERICA INC
# 857215                     CAPGEMINI AMERICA INC
#
#                                            SOC_NAME  \
# 0                         COMPUTER SYSTEMS ANALYSTS
# 1                  COMPUTER OCCUPATIONS, ALL OTHER*
# 2                 SOFTWARE DEVELOPERS, APPLICATIONS
# 3                            FILM AND VIDEO EDITORS
# 4       NETWORK AND COMPUTER SYSTEMS ADMINISTRATORS
# ...                                             ...
# 857211                    TRANSPORTATION INSPECTORS
# 857212                                      15-2031
# 857213                                          NaN
# 857214                                          NaN
# 857215                                          NaN
#
#                             SOC_CODE                       JOB_TITLE  \
# 0                            15-1121         SENIOR BUSINESS ANALYST
# 1                            15-1799       QUALITY ASSURANCE ANALYST
# 2                            15-1132          SR. SOFTWARE DEVELOPER
# 3                            27-4032                    VIDEO EDITOR
# 4                            15-1142           SYSTEMS ADMINISTRATOR
# ...                              ...                             ...
# 857211                       53-6051  SENIOR INVESTIGATOR AIR SAFETY
# 857212  OPERATIONS RESEARCH ANALYSTS     DIGITAL TOUCHPOINTS ANALYST
# 857213                           NaN       APPLICATIONS CONSULTANT 2
# 857214                           NaN      BUSINESS SYSTEMS ANALYST 2
# 857215                           NaN      BUSINESS SYSTEMS ANALYST 2
#
#        FULL_TIME_POSITION PREVAILING_WAGE     WORKSITE_CITY  \
# 0                       Y        109116.8      NORTH WALES,
# 1                       Y         58282.0         CAMP HILL
# 2                       Y         84906.0           CHICAGO
# 3                       Y         39333.0            AUBURN
# 4                       Y         68638.0          BETHPAGE
# ...                   ...             ...               ...
# 857211                  Y         74152.0  Long Island City
# 857212                  Y         75733.0           MADISON
# 857213                  Y         80704.0          DEARBORN
# 857214                  Y         74443.0          NEW YORK
# 857215                  Y         66643.0           MADISON
#
#        WORKSITE_STATE_ABB  YEAR WORKSITE_STATE_FULL  \
# 0                      PA  2015        PENNSYLVANIA
# 1                      PA  2015        PENNSYLVANIA
# 2                      IL  2015            ILLINOIS
# 3                      NY  2015            NEW YORK
# 4                      NY  2015            NEW YORK
# ...                   ...   ...                 ...
# 857211            NEWYORK  2019            NEW YORK
# 857212                 WI  2019           WISCONSIN
# 857213           MICHIGAN  2019            MICHIGAN
# 857214            NEWYORK  2019            NEW YORK
# 857215          WISCONSIN  2019           WISCONSIN
#
#                           WORKSITE
# 0        NORTH WALES, PENNSYLVANIA
# 1          CAMP HILL, PENNSYLVANIA
# 2                CHICAGO, ILLINOIS
# 3                 AUBURN, NEW YORK
# 4               BETHPAGE, NEW YORK
# ...                            ...
# 857211  Long Island City, NEW YORK
# 857212          MADISON, WISCONSIN
# 857213          DEARBORN, MICHIGAN
# 857214          NEW YORK, NEW YORK
# 857215          MADISON, WISCONSIN
#
# [857160 rows x 13 columns]

# %%
# Dropping unnecessary columns
columns_to_drop = ['SOC_CODE', 'CASE_NUMBER', 'WORKSITE', 'WORKSITE_STATE_ABB']
h1b_clean.drop(columns=columns_to_drop, errors='ignore', inplace=True)
h1b_clean.head()
# Out:
# <ipython-input-9-da591d388793>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h1b_clean.drop(columns=columns_to_drop, errors='ignore', inplace=True)
#            CASE_STATUS                         EMPLOYER_NAME  \
# 0            CERTIFIED                           IT CATS LLC
# 1  CERTIFIED-WITHDRAWN              XPERT TECHNOLOGIES, INC.
# 2            CERTIFIED                    ISR INFO WAY, INC.
# 3            CERTIFIED  MAGIC CIRCLE FILMS INTERNATIONAL LLC
# 4            WITHDRAWN                 SAPHIRE SOLUTIONS INC
#
#                                       SOC_NAME                  JOB_TITLE  \
# 0                    COMPUTER SYSTEMS ANALYSTS    SENIOR BUSINESS ANALYST
# 1             COMPUTER OCCUPATIONS, ALL OTHER*  QUALITY ASSURANCE ANALYST
# 2            SOFTWARE DEVELOPERS, APPLICATIONS     SR. SOFTWARE DEVELOPER
# 3                       FILM AND VIDEO EDITORS               VIDEO EDITOR
# 4  NETWORK AND COMPUTER SYSTEMS ADMINISTRATORS      SYSTEMS ADMINISTRATOR
#
#   FULL_TIME_POSITION PREVAILING_WAGE WORKSITE_CITY  YEAR WORKSITE_STATE_FULL
# 0                  Y        109116.8  NORTH WALES,  2015        PENNSYLVANIA
# 1                  Y         58282.0     CAMP HILL  2015        PENNSYLVANIA
# 2                  Y         84906.0       CHICAGO  2015            ILLINOIS
# 3                  Y         39333.0        AUBURN  2015            NEW YORK
# 4                  Y         68638.0      BETHPAGE  2015            NEW YORK

# %%
h1b_clean["CASE_STATUS"].value_counts()
# Out:
# CASE_STATUS
# CERTIFIED              765069
# CERTIFIED-WITHDRAWN     53045
# WITHDRAWN               27289
# DENIED                  11757
# Name: count, dtype: int64

# %%
#
h1b_clean['APPROVED'] = np.where(h1b_clean['CASE_STATUS'] == 'CERTIFIED', 1, 0)
# Out:
# <ipython-input-12-9055bd699bee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h1b_clean['APPROVED'] = np.where(h1b_clean['CASE_STATUS'] == 'CERTIFIED', 1, 0)

# %%
# Define target and features
X = h1b_clean.drop(columns=['APPROVED', 'CASE_STATUS'])
y = h1b_clean['APPROVED']

y[:10]
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    0
# 5    1
# 6    0
# 7    1
# 8    1
# 9    1
# Name: APPROVED, dtype: int64

# %%
X.head()
# Out:
#                           EMPLOYER_NAME  \
# 0                           IT CATS LLC
# 1              XPERT TECHNOLOGIES, INC.
# 2                    ISR INFO WAY, INC.
# 3  MAGIC CIRCLE FILMS INTERNATIONAL LLC
# 4                 SAPHIRE SOLUTIONS INC
#
#                                       SOC_NAME                  JOB_TITLE  \
# 0                    COMPUTER SYSTEMS ANALYSTS    SENIOR BUSINESS ANALYST
# 1             COMPUTER OCCUPATIONS, ALL OTHER*  QUALITY ASSURANCE ANALYST
# 2            SOFTWARE DEVELOPERS, APPLICATIONS     SR. SOFTWARE DEVELOPER
# 3                       FILM AND VIDEO EDITORS               VIDEO EDITOR
# 4  NETWORK AND COMPUTER SYSTEMS ADMINISTRATORS      SYSTEMS ADMINISTRATOR
#
#   FULL_TIME_POSITION PREVAILING_WAGE WORKSITE_CITY  YEAR WORKSITE_STATE_FULL
# 0                  Y        109116.8  NORTH WALES,  2015        PENNSYLVANIA
# 1                  Y         58282.0     CAMP HILL  2015        PENNSYLVANIA
# 2                  Y         84906.0       CHICAGO  2015            ILLINOIS
# 3                  Y         39333.0        AUBURN  2015            NEW YORK
# 4                  Y         68638.0      BETHPAGE  2015            NEW YORK

# %% [markdown]
# # Sampling Data

# %%
# Sample the data
X_sampled = X.sample(n=10000, random_state=42)
y_sampled = y[X_sampled.index]  # Keep the target variable corresponding to the sampled data

# %%
#Figures out categorical columns (strings)
encoding_columns = X_sampled.select_dtypes(include=['object']).columns
print("Categorical columns:", encoding_columns)
# Out:
# Categorical columns: Index(['EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE', 'FULL_TIME_POSITION',
#        'PREVAILING_WAGE', 'WORKSITE_CITY', 'YEAR', 'WORKSITE_STATE_FULL'],
#       dtype='object')

# %%
# one hot encoding
X_sampled_final = pd.get_dummies(X_sampled, drop_first=True)

# %%
X_sampled_final.head()
# Out:
#         EMPLOYER_NAME_12TH WONDER LLC  \
# 678888                          False
# 793632                          False
# 757942                          False
# 800905                          False
# 661709                          False
#
#         EMPLOYER_NAME_1385 WASHINGTON AVE PROPERTY ASSOCIATES, LLC.  \
# 678888                                              False
# 793632                                              False
# 757942                                              False
# 800905                                              False
# 661709                                              False
#
#         EMPLOYER_NAME_139 MEDICAL FACILITY, P.C.  \
# 678888                                     False
# 793632                                     False
# 757942                                     False
# 800905                                     False
# 661709                                     False
#
#         EMPLOYER_NAME_18|8 SOLUTIONS INC  \
# 678888                             False
# 793632                             False
# 757942                             False
# 800905                             False
# 661709                             False
#
#         EMPLOYER_NAME_1ST FAMILY DENTAL OF LOGAN SQUARE, INC.  \
# 678888                                              False
# 793632                                              False
# 757942                                              False
# 800905                                              False
# 661709                                              False
#
#         EMPLOYER_NAME_21 STAFF, LLC  EMPLOYER_NAME_22 STREET SAI LLC  \
# 678888                        False                            False
# 793632                        False                            False
# 757942                        False                            False
# 800905                        False                            False
# 661709                        False                            False
#
#         EMPLOYER_NAME_3CORE SYSTEMS, INC.  EMPLOYER_NAME_3EDGEUSAGROUP LLC  \
# 678888                              False                            False
# 793632                              False                            False
# 757942                              False                            False
# 800905                              False                            False
# 661709                              False                            False
#
#         EMPLOYER_NAME_3I INFOTECH, INC.  ...  YEAR_2017  YEAR_2018  YEAR_2019  \
# 678888                            False  ...      False      False      False
# 793632                            False  ...      False      False       True
# 757942                            False  ...      False      False      False
# 800905                            False  ...      False      False       True
# 661709                            False  ...      False      False      False
#
#         WORKSITE_STATE_FULL_INDIANA  WORKSITE_STATE_FULL_MICHIGAN  \
# 678888                        False                         False
# 793632                        False                         False
# 757942                        False                         False
# 800905                        False                         False
# 661709                        False                         False
#
#         WORKSITE_STATE_FULL_MINNESOTA  WORKSITE_STATE_FULL_NEW YORK  \
# 678888                          False                          True
# 793632                          False                         False
# 757942                          False                         False
# 800905                          False                          True
# 661709                          False                          True
#
#         WORKSITE_STATE_FULL_OHIO  WORKSITE_STATE_FULL_PENNSYLVANIA  \
# 678888                     False                             False
# 793632                     False                             False
# 757942                      True                             False
# 800905                     False                             False
# 661709                     False                             False
#
#         WORKSITE_STATE_FULL_WISCONSIN
# 678888                          False
# 793632                          False
# 757942                          False
# 800905                          False
# 661709                          False
#
# [5 rows x 14389 columns]

# %% [markdown]
# # Splitting Data

# %%
# Using train_test_split to split into training and testing data
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_train, X_test, y_train, y_test = train_test_split(X_sampled_final, y_sampled, test_size=0.2, random_state=42, stratify=y_sampled)

# %%
#Standardize the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)  # Fit and transform on training data
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Logistic Regression

# %%
# make the logistic regression model
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression(random_state=1)
classifier
# Out:
# LogisticRegression(random_state=1)

# %%
X_test_scaled # fit the model using the training data
classifier.fit(X_train_scaled, y_train)
classifier
# Out:
# LogisticRegression(random_state=1)

# %%
# score the model against the training data
print(f"Training Score: {classifier.score(X_train_scaled, y_train)}")
# Out:
# Training Score: 0.9985

# %%
# score the model against the testing data
print(f"Testing Score: {classifier.score(X_test_scaled, y_test)}")
# Out:
# Testing Score: 0.8555

# %%
# generate a list of predicted data based on the test data
# creates a df that shows the actual APPROVED values vs. the model’s predicted value
predictions = classifier.predict(X_test_scaled)
# compare the predictions to the actuals (y_test)
pd.DataFrame({
    "Actual": y_test.values,
    "Predicted": predictions
})
# Out:
#       Actual  Predicted
# 0          1          1
# 1          1          1
# 2          1          1
# 3          1          1
# 4          1          1
# ...      ...        ...
# 1995       1          1
# 1996       1          0
# 1997       1          1
# 1998       1          1
# 1999       1          1
#
# [2000 rows x 2 columns]

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
#Accuracy Score
print(f"Accuracy: {accuracy_score(y_test, predictions):.4f}")
# Out:
# Accuracy: 0.8555

# %%
#Confusion Matrix
cm = confusion_matrix(y_test, predictions)
cm
# Out:
# array([[  22,  203],
#        [  86, 1689]])

# %%
#Classification Report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.20      0.10      0.13       225
#            1       0.89      0.95      0.92      1775
#
#     accuracy                           0.86      2000
#    macro avg       0.55      0.52      0.53      2000
# weighted avg       0.82      0.86      0.83      2000

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#initializes random forest model
rf_classifier  = RandomForestClassifier(n_estimators=500, class_weight='balanced', random_state=42)

# %%
# fit the model
rf_classifier.fit(X_train_scaled, y_train)

# make predictions
rf_pred = rf_classifier.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# evaluate the model
accuracy = accuracy_score(y_test, rf_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.885

# %%
# confusion matrix
print(confusion_matrix(y_test, rf_pred))
# Out:
# [[   4  221]
#  [   9 1766]]

# %%
# classification report
print(classification_report(y_test, rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.31      0.02      0.03       225
#            1       0.89      0.99      0.94      1775
#
#     accuracy                           0.89      2000
#    macro avg       0.60      0.51      0.49      2000
# weighted avg       0.82      0.89      0.84      2000
